# %% [markdown]
# ## Data Lake vs Data Lakehouse: Implementação prática com Spark

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://databricks.com/blog/2021/08/30/frequently-asked-questions-about-the-data-lakehouse.html
#
# https://databricks.com/blog/2020/01/30/what-is-a-data-lakehouse.html
#
# https://aws.amazon.com/pt/big-data/datalakes-and-analytics/data-lake-house/
